# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Matplot

# %%
df0 = pd.read_csv('data_matplot\penguins.csv')
df0
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins_body_mass = df0['body_mass_g'].fillna(df0['body_mass_g'].mean())

# %%
fig, ax = plt.subplots(2,1)
ax[0].scatter(list(penguins_body_mass.index),penguins_body_mass)
ax[1].scatter(df0.index,df0['body_mass_g'])
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
df = pd.read_excel('data_matplot\data1.xlsx')
df
# Out:
#   name  kor  math
# 0  감하나   90    89
# 1  이정희   78    75
# 2  최선영   83    64
# 3  박영준   78    95
# 4  송정민   89   100

# %%
plt.plot(df['kor'], 'k--',marker = 'o')
plt.show()

# %%
plt.plot(df['kor'], 'k--',marker = 'o',label= 'korean')
plt.plot(df['math'], marker='^', label = 'math')
plt.legend()
plt.show()

# %%
x = [6,2,1,1,4,4,6,4,7,7]
y = [5,4,2,9,9,0,10,3,1,2]

plt.scatter(x,y)
plt.show()

# %%
x = np.arange(1,11)
y = np.random.randint(1,30,10)
plt.scatter(x,y)
plt.show()

# %%
x = ['A','B','C']
y = [100,150,120]

plt.bar(x,y)
plt.show()

# %%
k = [1,1,1,2,3,2,4]
plt.hist(k, bins = 8, color = 'green', align = 'left')
# bins: 구간을 나타내는 parameter
plt.show()

# %%
plt.bar(x,y)
plt.title('Test Graph')
plt.xlabel('Group')
plt.ylabel('Score')
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x,y)
axs[0,1].scatter(x,y)
axs[1,0].bar(x,y)
axs[1,1].barh(x,y)
fig.suptitle('Drawing Graph')
plt.show()

# %%
import matplotlib.font_manager as fm
fonts = sorted([a.name for a  in fm.fontManager.ttflist])
fonts
# Out:
# ['Agency FB',
#  'Agency FB',
#  'Algerian',
#  'Ami R',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial',
#  'Arial Rounded MT Bold',
#  'Bahnschrift',
#  'Baskerville Old Face',
#  'Batang',
#  'Bauhaus 93',
#  'Bell MT',
#  'Bell MT',
#  'Bell MT',
#  'Berlin Sans FB',
#  'Berlin Sans FB',
#  'Berlin Sans FB Demi',
#  'Bernard MT Condensed',
#  'Blackadder ITC',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Book Antiqua',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookman Old Style',
#  'Bookshelf Symbol 7',
#  'Bradley Hand ITC',
#  'Britannic Bold',
#  'Broadway',
#  'Brush Script MT',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Calibri',
#  'Californian FB',
# ...

# %%
plt.rc('font', family='Gulim')
x = [1, 2, 3, 4]
y = [10, 4, 15, 9]
plt.plot(x,y,label='국어')
plt.title('그래프 예제')
plt.xlabel('번호')
plt.ylabel('점수')
plt.legend()
plt.show()

# %%
df1 = pd.read_excel('data_matplot\data1.xlsx')
df1
# Out:
#   name  kor  math
# 0  감하나   90    89
# 1  이정희   78    75
# 2  최선영   83    64
# 3  박영준   78    95
# 4  송정민   89   100

# %%
x = df['kor']
y = df['math']
plt.plot(df['name'],x, 'k--', color = 'g',marker = 'o', label = '국어점수')
plt.plot(y, marker = '*',color = 'r', label = '수학점수')
plt.title('성적그래프')
plt.xlabel('이름')
plt.ylabel('점수')
plt.legend()
plt.show()
# Out:
# C:\Users\nasa1\AppData\Local\Temp\ipykernel_2424\3797037559.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(df['name'],x, 'k--', color = 'g',marker = 'o', label = '국어점수')

# %% [markdown]
# ## seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
sns.scatterplot(x ='petal_length',y = 'petal_width',hue = 'species',data = iris)
plt.title('Scatter Plot by seaborn', fontsize = 20)
plt.show()

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data = pd.read_csv('data_matplot\iris.csv')
sns.scatterplot(x = 'petal_length',y = 'petal_width',hue = 'species',data = iris_data)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.countplot(x = 'species', data = iris)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.barplot(x = 'species', y = 'petal_length', data = iris, errorbar ='sd')
plt.show()

# %%
sns.pairplot(iris, hue = 'species')
plt.show()
# Out:
# C:\Users\nasa1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot(x = 'petal_length', y = 'petal_width', data = iris)
plt.show()

# %%
df = iris.corr()
sns.heatmap(data=iris, annot = True, fmt = '.2f',cbar = False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = iris.corr()
#       2 sns.heatmap(data=iris, annot = True, fmt = '.2f',cbar = False)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
# ...

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.countplot(x = 'species', data = penguins, hue = 'sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.barplot(x = 'species', y = 'body_mass_g', data = penguins, hue = 'sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
df =penguins[['body_mass_g','bill_length_mm','bill_depth_mm','flipper_length_mm']].corr()
sns.heatmap(data=df, annot= True, fmt = '.2f', cbar = False)
# Out:
# <Axes: >

# %%
plt.scatter(penguins['bill_length_mm'], penguins['flipper_length_mm'])
