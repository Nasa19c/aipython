# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df0= df

# %%
df[['이름']]
# Out:
#     이름
# 0  구이서
# 1  김이정
# 2  오지수
# 3  김선후
# 4  하진희
# 5  강현진
# 6  김진솔
# 7  박서준
# 8  김성희
# 9  이지서

# %%
df.iloc[:4,0:4]
# df.loc[:4,'이름']
# Out:
#     반   이름 성별    국어
# 0  A반  구이서  남  90.0
# 1  B반  김이정  여  78.0
# 2  A반  오지수  남   NaN
# 3  B반  김선후  남  33.0

# %%
df[df['응시여부'] == '응시']
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인

# %%
df['합'] = df['국어'] + df['수학']

# %%
df.sort_values(by = ['합'],ascending = False)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부      합
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN

# %%
df = df0

# %%
list(df.index)
list(df.columns)
df.size
# Out:
# 80

# %%
df[df['수학']> df['수학'].mean()]
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부      합
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %%
df['반'].value_counts()
# Out:
# 반
# A반    5
# B반    5
# Name: count, dtype: int64

# %%
df.groupby('반')[['국어','수학']].sum()
# Out:
#                  이름     성별     국어     수학        응시여부      확인여부      합
# 반
# A반  구이서오지수하진희강현진김성희  남남여남남   90.0  174.0      응시응시응시    확인확인확인  264.0
# B반  김이정김선후김진솔박서준이지서  여남남여여  365.0  323.0  응시응시응시응시응시  확인확인확인확인  688.0

# %%
df.isna().sum()
# Out:
# 반       0
# 이름      0
# 성별      0
# 국어      3
# 수학      3
# 응시여부    2
# 확인여부    3
# 합       3
# dtype: int64

# %%
df.filln
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.filln
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'filln'
